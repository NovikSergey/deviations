# %%
import plotter
# Out:
# /home/sergey/code/statistics/env/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
analyzator = plotter.Stat_plotter()
analyzator.draw_plots('./deviation.json')
# Out:
# read json file
# save heatmap plot
# save bar distribution by corners
# save boxplot
# save bar stds
# filter data
# save boxplot
# save bar stds
# save bar comparison plot
# save mean histogram
# save suited distribution for histogram
# save comparison histogram
# save bar comparison mean plot
