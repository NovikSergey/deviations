# %%
import plotter

# %%
analyzator = plotter.Stat_plotter()
analyzator.draw_plots('./deviation.json')
# Out:
# ['./plots/heatmap.png',
#  './plots/Distribution_by_number_of_corners.png',
#  './plots/Estimation_without_filtering.png',
#  './plots/Comparison_stds_without_filtering.png',
#  './plots/Estimation_with_filtering.png',
#  './plots/Comparison_stds_with_filtering.png',
#  './plots/Comparison.png',
#  './plots/Mean_histogram.png',
#  './plots/Suited_distribution.png',
#  './plots/Comparison_floor_ceiling_histogram.png',
#  './plots/Comparison_means_ranges.png']
